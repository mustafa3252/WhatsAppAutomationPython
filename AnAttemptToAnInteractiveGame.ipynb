# %%
import random

# welcoming user
print("Welcome to my first game!\n")
name = input("What is your name? ")
age = int(input("What is your age? "))

if age >= 18:
    print("Hello {}! the game is set for you.".format(name))

else:
    print("Hello", name, "you are", age, "years old" )

# if above 18 years old, assigning health points
health = 10

print("You are starting with {} health.".format(health) )

is_older = age >= 18 #assigning boolean value to a variable

# intro to the game

if is_older == True:
    print("You are being assigned a mission to search for The Gauntlet Of Shikawa and bring it back to Britain. You will be deployed in the Amazon forest, closet to  where the intelligence thinks the Gauntlet is hidden. From that point, you will have to continue the rest of the mission alone.")


    wants_to_play = input("Do you still wanna play? ").lower()
    
    if wants_to_play == "yes":

        print("Let's play!")
        
        # taking input for the firt choice from the user 

        left_or_right = input("First choice... Left or Right (left/right)? ").lower()

        if left_or_right == "left":
            
            # second inout form the user
            
            ans = input("Nice, you follow the path and reach a lake... Do you swim across or go around (across/around)? ").lower()

            #consequences of second choice
            
            if ans == "around":

                print("You went around and reached the other side of the lake.")

            elif ans == "across":

                print("You managed to get across, but were bit by a snake swimming in the lake and lost 5 health.")

                health -= 5

                print("Your are left with {} health now.".format(health))
                
                # third input from the user

            ans = input("You see a strange looking temple ahead. The temple has faces of some kind of devilish creatures sculpted on it. There are two tunnels leading inside the temple. Which one do you take... Left or Right (left/right)? ").lower()

            # consequences of second choice 
            
            if ans == "right":

                    print("You seemed to have avoided all the traps but are terribly wounded.")

                    health -= 3

                    print("Your are left with {} health now.".format(health))

                    # rondomizing two integers and assigning them to a variable.
                    
                    carring_weapon_probability = random.randint(0,1)

                    print("You are now inside the temple. The priceless Gauntlet in front of you. You are feeling like this is the greatest acheivement of your life. You hear a soft thud. You suspect something moving and BANG!\nYou are hit on your head with a solid peice of rock. Your head is bleeding! You fall on the floor, hastily search for your weapon.")

                    health -= 1

                    print("Your health is reduced.")

                    print("Your are left with {} health now.".format(health))
                    
                    # use of the varibale assigned the random int

                    if carring_weapon_probability == 1:

                        print("You find your weapon and start to look for that creature. It appears all of the sudden running towards you. You dodge its attack and with your weapon you succesfully defeat it.\nThere seems on obstacle left now. You now have the precious Gauntlet of Shikawa.\nYou have succeeded in your mission.\nCongratulation Agent {} you succeeded with {} health left !!!".format(name, health))

                    else:
                        print("Wait... you realize you lost your weapon on the way to the temple and being defenseless, you are killed by the creature. You lost... ")

                # case where player chooses "left" for the second input         

            else:
                    print("The left tunnel seems to have been a tunnel for you to move from this life to next. You are dead. RIP.") 
            
            # case where player chooses "right" for the first input 
                    
        else:
            print("You fell down the clif and lost...")
    
    # case where player says no to play
            
    else:

        print("Coward...")
        
      # case where player is between [14,17]  

elif age >= 14:
    print("You can play with supervision.")
    
    # case where player is less than 14 years old
    
else:
    print("You are not old enough to play.")
